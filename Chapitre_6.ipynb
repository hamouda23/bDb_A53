# %% [markdown]
# <a href="https://colab.research.google.com/github/hamouda23/bDb_A53/blob/master/Chapitre_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

# Téléchargement du fichier depuis votre machine
uploaded = files.upload()
# Out:
#      <input type="file" id="files-15b089f9-b52e-4815-82c3-3067b531ce95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15b089f9-b52e-4815-82c3-3067b531ce95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('iris.csv')
df.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
nom_classe = df['species'].unique()
print(f"Les classes : {nom_classe}")
nombre_classe = len(nom_classe)
print(f"Le nombre de classe : {nombre_classe}")
# Out:
# Les classes : ['setosa' 'versicolor' 'virginica']
# Le nombre de classe : 3

# %%
#individue_classe = df['species'].value_counts()
#print(f"Individue par classe : \n{individue_classe}")
df.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
#entre  = df.iloc[:, :-1] # toute les colonnes sauf species
#sortie = df.iloc[: ,-1] # la dernire colonne

# %%
train, test = train_test_split(df, test_size=0.5, random_state=10, stratify=df['species'])
print("Distribution des classes dans l'ensemble test :")
test.groupby('species').size()
# Out:
# Distribution des classes dans l'ensemble test :
# species
# setosa        25
# versicolor    25
# virginica     25
# dtype: int64

# %%
sns.pairplot(df ,hue='species' ,diag_kind='kde')

# %%
train, test = train_test_split(df, test_size=0.3, random_state=10, stratify=df['species'])
test.groupby('species').size()
train.groupby('species').size()
# Out:
# species
# setosa        35
# versicolor    35
# virginica     35
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
#x

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10, stratify=y)
print(f"x_train shape: {x_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: (105, 4)
# x_test shape: (45, 4)
# y_train shape: (105,)
# y_test shape: (45,)

# %%
model = DecisionTreeClassifier(max_depth=3, random_state=1)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1)

# %%
fn = x_train.columns
cn = y_train.unique()
plt.figure(figsize=(12, 8))
plot_tree(model, feature_names=fn, class_names=cn, filled=True, rounded=True)
plt.title("Arbre de décision (Iris Dataset)")
# Out:
# Text(0.5, 1.0, 'Arbre de décision (Iris Dataset)')
